# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
ser1 = Series(np.arange(3), index=['A','B','C'])

ser1 = 2 * ser1

ser1
# Out:
# A    0
# B    2
# C    4
# dtype: int64

# %%
ser1['B']
# Out:
# 2

# %%
ser1[1]
# Out:
# 2

# %%
ser1[0:3]
# Out:
# A    0
# B    2
# C    4
# dtype: int64

# %%
ser1[['A','B']]
# Out:
# A    0
# B    2
# dtype: int64

# %%
ser1[ser1 > 3]
# Out:
# C    4
# dtype: int64

# %%
ser1[ser1 > 3] = 10

# %%
ser1
# Out:
# A     0
# B     2
# C    10
# dtype: int64

# %%
dframe = DataFrame(np.arange(25).reshape((5,5)), index=['NY','LA','SF','DC','Chicago'],
                  columns=['A','B','C','D','E'])

# %%
dframe
# Out:
#           A   B   C   D   E
# NY        0   1   2   3   4
# LA        5   6   7   8   9
# SF       10  11  12  13  14
# DC       15  16  17  18  19
# Chicago  20  21  22  23  24

# %%
dframe['B']
# Out:
# NY          1
# LA          6
# SF         11
# DC         16
# Chicago    21
# Name: B, dtype: int64

# %%
dframe[['B','E']]
# Out:
#           B   E
# NY        1   4
# LA        6   9
# SF       11  14
# DC       16  19
# Chicago  21  24

# %%
dframe[dframe['C'] > 8]
# Out:
#           A   B   C   D   E
# SF       10  11  12  13  14
# DC       15  16  17  18  19
# Chicago  20  21  22  23  24

# %%
dframe
# Out:
#           A   B   C   D   E
# NY        0   1   2   3   4
# LA        5   6   7   8   9
# SF       10  11  12  13  14
# DC       15  16  17  18  19
# Chicago  20  21  22  23  24

# %%
dframe > 10
# Out:
#              A      B      C      D      E
# NY       False  False  False  False  False
# LA       False  False  False  False  False
# SF       False   True   True   True   True
# DC        True   True   True   True   True
# Chicago   True   True   True   True   True

# %%
dframe.ix['LA']
# Out:
# A    5
# B    6
# C    7
# D    8
# E    9
# Name: LA, dtype: int64

# %%
dframe.ix[1]
# Out:
# A    5
# B    6
# C    7
# D    8
# E    9
# Name: LA, dtype: int64

# %%
dframe.iloc[1,3]
# Out:
# 8

# %%
dframe
# Out:
#           A   B   C   D   E
# NY        0   1   2   3   4
# LA        5   6   7   8   9
# SF       10  11  12  13  14
# DC       15  16  17  18  19
# Chicago  20  21  22  23  24

# %%
dframe.iloc[1]
# Out:
# A    5
# B    6
# C    7
# D    8
# E    9
# Name: LA, dtype: int64

# %%
dframe.iloc[1,3]
# Out:
# 8

# %%
dframe['A']
# Out:
# NY          0
# LA          5
# SF         10
# DC         15
# Chicago    20
# Name: A, dtype: int64

# %%
dframe.iloc[1]
# Out:
# A    5
# B    6
# C    7
# D    8
# E    9
# Name: LA, dtype: int64

# %%
dframe.ix['LA']
# Out:
# A    5
# B    6
# C    7
# D    8
# E    9
# Name: LA, dtype: int64
